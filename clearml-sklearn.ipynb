# %% [markdown]
# # Setup
# - install the package `pip install clearml`
# - sign up an account at [https://clear.ml/](https://clear.ml/) and create clearml credentials at [https://app.clear.ml/settings/workspace-configuration](https://app.clear.ml/settings/workspace-configuration)
# - run `clearml-init` and follow the setup instructions

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('seaborn')

# %%
# read csv data into pandas dataframe
df = pd.read_csv('titanic.csv')
# axis = 1 below means dropping by columns, 0 means by rows
X = df.drop(['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
y = df['Survived']

# %%
# a task is an experiment
from clearml import Task

task1 = Task.init(project_name='mini machine learning tutorial', task_name='Decision Tree')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb Cell 4' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000006?line=0'>1</a> # a task is an experiment
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000006?line=1'>2</a> from clearml import Task
# ----> <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000006?line=3'>4</a> task1 = Task.init(project_name='mini machine learning tutorial', task_name='Decision Tree')
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py:506, in Task.init(cls, project_name, task_name, task_type, tags, reuse_last_task_id, continue_last_task, output_uri, auto_connect_arg_parser, auto_connect_frameworks, auto_resource_monitoring, auto_connect_streams)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=502'>503</a> if not running_remotely():
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=503'>504</a>     # if this is the main process, create the task
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=504'>505</a>     if not is_sub_process_task_id:
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=505'>506</a>         task = cls._create_dev_task(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=506'>507</a>             default_project_name=project_name,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=507'>508</a>             default_task_name=task_name,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=508'>509</a>             default_task_type=task_type,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=509'>510</a>             tags=tags,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=510'>511</a>             reuse_last_task_id=reuse_last_task_id,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=511'>512</a>             continue_last_task=continue_last_task,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=512'>513</a>             detect_repo=False if (
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=513'>514</a>                     isinstance(auto_connect_frameworks, dict) and
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=514'>515</a>                     not auto_connect_frameworks.get('detect_repository', True)) else True,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=515'>516</a>             auto_connect_streams=auto_connect_streams,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=516'>517</a>         )
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=517'>518</a>         # set defaults
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=518'>519</a>         if cls._offline_mode:
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py:2776, in Task._create_dev_task(cls, default_project_name, default_task_name, default_task_type, tags, reuse_last_task_id, continue_last_task, detect_repo, auto_connect_streams)
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2773'>2774</a> # create a new task
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2774'>2775</a> if not default_task_id:
# -> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2775'>2776</a>     task = cls(
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2776'>2777</a>         private=cls.__create_protection,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2777'>2778</a>         project_name=default_project_name,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2778'>2779</a>         task_name=default_task_name,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2779'>2780</a>         task_type=default_task_type,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2780'>2781</a>         log_to_backend=True,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2781'>2782</a>     )
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2782'>2783</a>     # no need to reload yet, we clear this before the end of the function
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2783'>2784</a>     task._reload_skip_flag = True
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py:169, in Task.__init__(self, private, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=164'>165</a>     raise UsageError(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=165'>166</a>         'Task object cannot be instantiated externally, use Task.current_task() or Task.get_task(...)')
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=166'>167</a> self._repo_detect_lock = threading.RLock()
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=168'>169</a> super(Task, self).__init__(**kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=169'>170</a> self._arguments = _Arguments(self)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=170'>171</a> self._logger = None
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py:152, in Task.__init__(self, session, task_id, log, project_name, task_name, task_type, log_to_backend, raise_on_validation_errors, force_create)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=149'>150</a> task_id = self._resolve_task_id(task_id, log=log) if not force_create else None
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=150'>151</a> self.__edit_lock = None
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=151'>152</a> super(Task, self).__init__(id=task_id, session=session, log=log)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=152'>153</a> self._project_name = None
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=153'>154</a> self._storage_uri = None
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py:145, in IdObjectBase.__init__(self, id, session, log, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=143'>144</a> def __init__(self, id, session=None, log=None, **kwargs):
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=144'>145</a>     super(IdObjectBase, self).__init__(session, log, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=145'>146</a>     self._data = None
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=146'>147</a>     self._id = None
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py:39, in InterfaceBase.__init__(self, session, log, **kwargs)
#      <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=36'>37</a> def __init__(self, session=None, log=None, **kwargs):
#      <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=37'>38</a>     super(InterfaceBase, self).__init__()
# ---> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=38'>39</a>     self._session = session or self._get_default_session()
#      <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=39'>40</a>     self._log = log or self._create_log()
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py:115, in InterfaceBase._get_default_session(cls)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=111'>112</a> @classmethod
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=112'>113</a> def _get_default_session(cls):
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=113'>114</a>     if not InterfaceBase._default_session:
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=114'>115</a>         InterfaceBase._default_session = Session(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=115'>116</a>             initialize_logging=False,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=116'>117</a>             config=config_obj,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=117'>118</a>             api_key=ENV_ACCESS_KEY.get(),
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=118'>119</a>             secret_key=ENV_SECRET_KEY.get(),
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=119'>120</a>         )
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=120'>121</a>     return InterfaceBase._default_session
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py:176, in Session.__init__(self, worker, api_key, secret_key, host, logger, verbose, initialize_logging, config, http_retries_config, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=172'>173</a>     raise ValueError("host is required in init or config")
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=174'>175</a> if not self._offline_mode and ENV_CLEARML_NO_DEFAULT_SERVER.get() and host == self.default_demo_host:
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=175'>176</a>     raise ValueError(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=176'>177</a>         "ClearML configuration could not be found (missing `~/clearml.conf` or Environment CLEARML_API_HOST)\n"
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=177'>178</a>         "To get started with ClearML: setup your own `clearml-server`, "
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=178'>179</a>         "or create a free account at https://app.clear.ml"
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=179'>180</a>     )
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=181'>182</a> self._ssl_error_count_verbosity = self.config.get(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=182'>183</a>     "api.ssl_error_count_verbosity", self._ssl_error_count_verbosity)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=184'>185</a> self.__host = host.strip("/")
#
# ValueError: ClearML configuration could not be found (missing `~/clearml.conf` or Environment CLEARML_API_HOST)
# To get started with ClearML: setup your own `clearml-server`, or create a free account at https://app.clear.ml

# %%
configuration_dict = {
    'test_size': 0.2,
    'split_random_state': 42,
    'criterion': 'entropy',
    'max_depth': 7,
    }

configuration_dict = task1.connect(configuration_dict)  # enabling configuration override by clearml

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=configuration_dict.get('test_size'), 
    random_state=configuration_dict.get('split_random_state'),
)

# %%
# log table to ClearML
logger = task1.get_logger()
logger.report_table(title='Train Dataset', series='first 10 lines', iteration=1, table_plot=X_train.head(10))
logger.report_table(title='Test Dataset', series='first 10 lines', iteration=1, table_plot=X_test.head(10))

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
import joblib

num_features = ['Age', 'SibSp', 'Parch', 'Fare']
cat_features = ['Sex', 'Embarked', 'Pclass']

num_pipeline = Pipeline(
    steps=[
        ('num_imputer', SimpleImputer()),
        ('scaler', StandardScaler()),
        ]
)

cat_pipeline = Pipeline(
    steps=[
        ('cat_imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder()),
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ('num_pipeline', num_pipeline, num_features),
        ('cat_pipeline', cat_pipeline, cat_features),
    ]
)

pipeline_dt = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('clf_dt', DecisionTreeClassifier(
            criterion=configuration_dict.get('criterion'),
            max_depth=configuration_dict.get('max_depth')),
            ),
    ]
)

from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate

scoring = ['accuracy', 'precision', 'recall', 'f1']

cv_scores_dt = cross_validate(pipeline_dt, X_train, y_train, scoring=scoring, cv=10, return_train_score=True)

fig, ax = plt.subplots(figsize=(20, 5))

ax.plot(cv_scores_dt['train_accuracy'], '-', label='train accuracy')
ax.plot(cv_scores_dt['test_accuracy'], '--', label='test accuracy')
ax.set_title('train/test accuracy')
ax.legend()

logger.report_matplotlib_figure('train/test accuracy', '', fig, iteration=1)

model_dt = pipeline_dt.fit(X_train, y_train)

y_pred = model_dt.predict(X_test)

print(f'Final Accuracy Score : {accuracy_score(y_test, y_pred)}')

joblib.dump(model_dt, 'model_dt.pkl', compress=True)

task1.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=0'>1</a> # a task is an experiment
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=1'>2</a> from clearml import Task
# ----> <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=2'>3</a> task1 = Task.init(project_name='mini machine learning tutorial', task_name='Decision Tree')
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=3'>4</a> configuration_dict = {
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=4'>5</a>     'test_size': 0.2,
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=5'>6</a>     'split_random_state': 42,
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=6'>7</a>     'criterion': 'entropy',
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=7'>8</a>     'max_depth': 7,
#       <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=8'>9</a>     }
#      <a href='vscode-notebook-cell:/Users/harrywang/sandbox/mini-ml/mini-ml-clearml.ipynb#ch0000003?line=10'>11</a> configuration_dict = task1.connect(configuration_dict)  # enabling configuration override by clearml
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py:506, in Task.init(cls, project_name, task_name, task_type, tags, reuse_last_task_id, continue_last_task, output_uri, auto_connect_arg_parser, auto_connect_frameworks, auto_resource_monitoring, auto_connect_streams)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=502'>503</a> if not running_remotely():
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=503'>504</a>     # if this is the main process, create the task
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=504'>505</a>     if not is_sub_process_task_id:
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=505'>506</a>         task = cls._create_dev_task(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=506'>507</a>             default_project_name=project_name,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=507'>508</a>             default_task_name=task_name,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=508'>509</a>             default_task_type=task_type,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=509'>510</a>             tags=tags,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=510'>511</a>             reuse_last_task_id=reuse_last_task_id,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=511'>512</a>             continue_last_task=continue_last_task,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=512'>513</a>             detect_repo=False if (
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=513'>514</a>                     isinstance(auto_connect_frameworks, dict) and
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=514'>515</a>                     not auto_connect_frameworks.get('detect_repository', True)) else True,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=515'>516</a>             auto_connect_streams=auto_connect_streams,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=516'>517</a>         )
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=517'>518</a>         # set defaults
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=518'>519</a>         if cls._offline_mode:
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py:2776, in Task._create_dev_task(cls, default_project_name, default_task_name, default_task_type, tags, reuse_last_task_id, continue_last_task, detect_repo, auto_connect_streams)
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2773'>2774</a> # create a new task
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2774'>2775</a> if not default_task_id:
# -> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2775'>2776</a>     task = cls(
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2776'>2777</a>         private=cls.__create_protection,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2777'>2778</a>         project_name=default_project_name,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2778'>2779</a>         task_name=default_task_name,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2779'>2780</a>         task_type=default_task_type,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2780'>2781</a>         log_to_backend=True,
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2781'>2782</a>     )
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2782'>2783</a>     # no need to reload yet, we clear this before the end of the function
#    <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=2783'>2784</a>     task._reload_skip_flag = True
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py:169, in Task.__init__(self, private, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=164'>165</a>     raise UsageError(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=165'>166</a>         'Task object cannot be instantiated externally, use Task.current_task() or Task.get_task(...)')
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=166'>167</a> self._repo_detect_lock = threading.RLock()
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=168'>169</a> super(Task, self).__init__(**kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=169'>170</a> self._arguments = _Arguments(self)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/task.py?line=170'>171</a> self._logger = None
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py:152, in Task.__init__(self, session, task_id, log, project_name, task_name, task_type, log_to_backend, raise_on_validation_errors, force_create)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=149'>150</a> task_id = self._resolve_task_id(task_id, log=log) if not force_create else None
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=150'>151</a> self.__edit_lock = None
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=151'>152</a> super(Task, self).__init__(id=task_id, session=session, log=log)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=152'>153</a> self._project_name = None
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/task/task.py?line=153'>154</a> self._storage_uri = None
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py:145, in IdObjectBase.__init__(self, id, session, log, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=143'>144</a> def __init__(self, id, session=None, log=None, **kwargs):
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=144'>145</a>     super(IdObjectBase, self).__init__(session, log, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=145'>146</a>     self._data = None
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=146'>147</a>     self._id = None
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py:39, in InterfaceBase.__init__(self, session, log, **kwargs)
#      <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=36'>37</a> def __init__(self, session=None, log=None, **kwargs):
#      <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=37'>38</a>     super(InterfaceBase, self).__init__()
# ---> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=38'>39</a>     self._session = session or self._get_default_session()
#      <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=39'>40</a>     self._log = log or self._create_log()
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py:115, in InterfaceBase._get_default_session(cls)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=111'>112</a> @classmethod
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=112'>113</a> def _get_default_session(cls):
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=113'>114</a>     if not InterfaceBase._default_session:
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=114'>115</a>         InterfaceBase._default_session = Session(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=115'>116</a>             initialize_logging=False,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=116'>117</a>             config=config_obj,
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=117'>118</a>             api_key=ENV_ACCESS_KEY.get(),
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=118'>119</a>             secret_key=ENV_SECRET_KEY.get(),
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=119'>120</a>         )
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_interface/base.py?line=120'>121</a>     return InterfaceBase._default_session
#
# File ~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py:176, in Session.__init__(self, worker, api_key, secret_key, host, logger, verbose, initialize_logging, config, http_retries_config, **kwargs)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=172'>173</a>     raise ValueError("host is required in init or config")
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=174'>175</a> if not self._offline_mode and ENV_CLEARML_NO_DEFAULT_SERVER.get() and host == self.default_demo_host:
# --> <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=175'>176</a>     raise ValueError(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=176'>177</a>         "ClearML configuration could not be found (missing `~/clearml.conf` or Environment CLEARML_API_HOST)\n"
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=177'>178</a>         "To get started with ClearML: setup your own `clearml-server`, "
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=178'>179</a>         "or create a free account at https://app.clear.ml"
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=179'>180</a>     )
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=181'>182</a> self._ssl_error_count_verbosity = self.config.get(
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=182'>183</a>     "api.ssl_error_count_verbosity", self._ssl_error_count_verbosity)
#     <a href='file:///~/sandbox/mini-ml/venv/lib/python3.9/site-packages/clearml/backend_api/session/session.py?line=184'>185</a> self.__host = host.strip("/")
#
# ValueError: ClearML configuration could not be found (missing `~/clearml.conf` or Environment CLEARML_API_HOST)
# To get started with ClearML: setup your own `clearml-server`, or create a free account at https://app.clear.ml

# %%
# a task is an experiment
from clearml import Task
task2 = Task.init(project_name='mini machine learning tutorial', task_name='Support Vector Machine')
configuration_dict = {
    'test_size': 0.2,
    'split_random_state': 42,
    }

configuration_dict = task2.connect(configuration_dict)  # enabling configuration override by clearml

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=configuration_dict.get('test_size'), 
    random_state=configuration_dict.get('split_random_state'),
)

# log table to ClearML
logger = task2.get_logger()
logger.report_table(title='Train Dataset', series='first 10 lines', iteration=1, table_plot=X_train.head(10))
logger.report_table(title='Test Dataset', series='first 10 lines', iteration=1, table_plot=X_test.head(10))

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVC
import joblib

num_features = ['Age', 'SibSp', 'Parch', 'Fare']
cat_features = ['Sex', 'Embarked', 'Pclass']

num_pipeline = Pipeline(
    steps=[
        ('num_imputer', SimpleImputer()),
        ('scaler', StandardScaler()),
        ]
)

cat_pipeline = Pipeline(
    steps=[
        ('cat_imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder()),
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ('num_pipeline', num_pipeline, num_features),
        ('cat_pipeline', cat_pipeline, cat_features),
    ]
)

pipeline_svc = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('clf_svc', SVC()),
    ]
)

from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate

scoring = ['accuracy', 'precision', 'recall', 'f1']

cv_scores_svc = cross_validate(pipeline_svc, X_train, y_train, scoring=scoring, cv=10, return_train_score=True)

fig, ax = plt.subplots(figsize=(20, 5))

ax.plot(cv_scores_svc['train_accuracy'], '-', label='train accuracy')
ax.plot(cv_scores_svc['test_accuracy'], '--', label='test accuracy')
ax.set_title('train/test accuracy')
ax.legend()

logger.report_matplotlib_figure('train/test accuracy', '', fig, iteration=1)

model_svc = pipeline_svc.fit(X_train, y_train)

y_pred = model_svc.predict(X_test)

print(f'Final Accuracy Score : {accuracy_score(y_test, y_pred)}')

joblib.dump(model_svc, 'model_svc.pkl', compress=True)

task2.close()
# Out:
# ClearML Task: created new task id=2adf81313f1f4abcad8b9b1463a2101d
# 2021-07-12 16:11:19,692 - clearml.Task - WARNING - Failed auto-detecting task repository: Script file [PosixPath('/Users/harrywang/sandbox/mini-ml/ipykernel_launcher'), PosixPath('/var/folders/pj/bgdff0390xgg_836zl2q91dh0000gn/T/ipykernel_84009/2161780232.py')] could not be found
# ClearML results page: https://app.community.clear.ml/projects/c9efa9f954864aed826f6cd13b272faf/experiments/2adf81313f1f4abcad8b9b1463a2101d/output/log
# ClearML Monitor: GPU monitoring failed getting GPU reading, switching off GPU monitoring
# Final Accuracy Score : 0.8156424581005587
